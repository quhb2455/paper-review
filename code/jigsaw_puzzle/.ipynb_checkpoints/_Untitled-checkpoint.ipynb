# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset,DataLoader
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

import cv2
import os
from glob import glob
from tqdm import tqdm
import numpy as np

from itertools import permutations
from scipy.spatial import distance

# %%
class AlexNet(nn.Module) :
    def __init__(self, 
                 first_in=3, 
                 first_stride=4, 
                 dropout_rate=0.5, 
                 in_feature=256*6*6,
                 out_feature=4608,
                 num_classes=1000
                ) :
        super(AlexNet, self).__init__()
        self.conv_1 = nn.Sequential(
            nn.Conv2d(in_channels=first_in, 
                      out_channels=96, 
                      kernel_size=11, 
                      padding=2, 
                      stride=first_stride),
            nn.ReLU(),
            nn.LocalResponseNorm(size=5, 
                                 k=2,    
                                 alpha=0.0001, 
                                 beta=0.75),
            nn.MaxPool2d(kernel_size=3, 
                        stride=2),
        )
        
        self.conv_2 = nn.Sequential(
            nn.Conv2d(in_channels=96, 
                     out_channels=256,
                      padding=2,
                      kernel_size=5),
            nn.ReLU(),
            nn.LocalResponseNorm(size=5, 
                                 k=2,    
                                 alpha=0.0001, 
                                 beta=0.75),
            nn.MaxPool2d(kernel_size=3, 
                        stride=2),
        )
        
        self.conv_3 = nn.Sequential(
            nn.Conv2d(in_channels=256, 
                     out_channels=384,
                      padding=1,
                      kernel_size=3),
            nn.ReLU(),
        )
        
        self.conv_4 = nn.Sequential(
            nn.Conv2d(in_channels=384, 
                     out_channels=384,
                      padding=1,
                      kernel_size=3),
            nn.ReLU(),
        )
        
        self.conv_5 = nn.Sequential(
            nn.Conv2d(in_channels=384, 
                     out_channels=256,
                      padding=1,
                      kernel_size=3,
                     ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, 
                         stride=2),
        )
                
        self.conv_layers = nn.Sequential(
            self.conv_1, 
            self.conv_2, 
            self.conv_3, 
            self.conv_4, 
            self.conv_5, 
        )
        
        self.fc_layers = nn.Sequential(
            nn.Linear(in_feature, out_feature),
            nn.ReLU(),
            nn.Dropout(p=dropout_rate),
            nn.Linear(out_feature, out_feature),
            nn.ReLU(),
            nn.Dropout(p=dropout_rate),
            nn.Linear(out_feature, num_classes),
        )

        
        for idx, layers in enumerate(self.conv_layers):
            self.initialization(idx, layers)

        self.initialization('fc', self.fc_layers)

    def initialization(self, idx, layers) :
        for layer in layers :
            if 'weight' in dir(layer):
                nn.init.normal_(layer.weight, mean=0, std=0.01)                
                if idx in ['fc', 1, 3, 4] :
                    nn.init.constant_(layer.bias.data, 1)
                elif idx in [0, 2] :
                    nn.init.constant_(layer.bias.data, 0)    
                    
    def forward(self, x) :
        x = self.conv_layers(x)
        # x = x.contiguous().view(-1) 

        x = x.flatten(1)

        x = self.fc_layers(x)
        return x

# %%
class CFN(nn.Module) :
    def __init__(self, 
                 in_channel=27, 
                 strd=2, 
                 in_feature=256*3*3, 
                 out_feature=4608, 
                 num_classes=100) :
        super(CFN, self).__init__()
        self.alexnet = AlexNet(first_in=in_channel, 
                               first_stride=strd, 
                               in_feature=in_feature, 
                               out_feature=out_feature
                              )
        # alexnet 논문에 나와있는 방법으로 초기화한 layer들을 가져옴
        self.conv_layers = self.alexnet.conv_layers
        self.fc6 = self.alexnet.fc_layers[0]
        
        # fc7, fc8, output 포함
        self.classifier = nn.Sequential(
            nn.Linear(out_feature, 4096), 
            nn.ReLU(),
            nn.Linear(4096, 100), 
            nn.ReLU(),
            nn.Linear(100, num_classes)
        )
        
        self.alexnet.initialization('fc', self.classifier)
        
    def forward(self, x) :
        x = self.conv_layers(x)
        x = x.flatten(1)
        x = self.fc6(x)
        x = self.classifier(x)
        return x

# %%
class jigsaw_pipeline() :
    def __init__(self, normalize=True, color_jitter=False) :
        self.color_jitter = color_jitter
        
        if normalize :
            self.transforms = A.Compose([
                A.RandomCrop(64, 64),
                A.Normalize()
            ])
        else : 
            self.transforms = A.Compose([
                A.RandomCrop(64, 64)
            ])
            
    def __call__(self, img) :
        h, w, c = img.shape
        
        # step 1. resize width or height to 256 with preserve the original aspect ratio.
        if h < w :
            resized_w = int(w / h * 256)
            img = cv2.resize(img, (256 , resized_w))

        elif w <= h :
            resized_h = int(h / w * 256)
            img = cv2.resize(img, (resized_h, 256))
        
        # step 2. Random crop size 225 x 225
        img = A.RandomCrop(225, 225)(image = img)['image']
        
        # step 3 and 4. split 3 x 3 grid of 75 x 75 pixels tiles and random crop 64 x 64
        for i in range(3) :
            for j in range(3) :
                crop_img = img[i*75 : (i * 75) + 75, j*75 : (j * 75) + 75, :]
                
                if i == 0 and j == 0 :    
                    tile_img = self.transforms(image = crop_img)['image']
                else : 
                    tile_img = np.concatenate((tile_img,self.transforms(image = crop_img)['image']),axis=2)
        
        return tile_img

# %%
def generate_permutation_sets(number_permu_set=100, max_hamming=True, save=True) :

    item = [i for i in range(1,10)]
    permutate_items = np.array(list(permutations(item, 9)))
    max_hamming = True

    N = number_permu_set # permutation 개수
    j = np.random.choice(len(permutate_items), 1, replace=False)

    for i in tqdm(range(1, N+1)) :
        if i == 1 :
            p = np.array(permutate_items[j])
        else : 
            hat_p = np.array(permutate_items[j]).reshape([1, -1])
            p = np.concatenate([p, hat_p], axis=0)

        permutate_items = np.delete(permutate_items, j, axis=0)
        d = distance.cdist(p, permutate_items, metric='hamming').mean(axis=0)

        if max_hamming == True :
            j = np.argmax(d)
        else : 
            j = np.argmin(d)
            
    if save :
        np.save(f'permutation_{N}_sets.npy', p)
    
    return p

# %%
class JIGSAW_DATASET(Dataset) :
    def __init__(self, img_list, permu_set, normalize=True) :
        self.img_list = img_list
        self.permu_set = permu_set
        self.pipeline = jigsaw_pipeline(normalize=normalize)
    
    def __len__(self) :
        return len(self.img_list)
    
    def shuffle_tiles(self, tile, permu):
        shuffled_tile = np.zeros_like(tile)
        for idx, num in enumerate(permu, start=1) :
            shuffled_tile[:, :, (idx-1)*3 : idx*3] = tile[:, :, (num-1) * 3 : num * 3]
        return shuffled_tile
            
    def __getitem__(self, idx) :
        img = cv2.imread(self.img_list[idx])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = self.pipeline(img)
        
        permu_idx = np.random.randint(self.permu_set.shape[0])        
        permu = self.permu_set[permu_idx]
        
        img = self.shuffle_tiles(img, permu)
        img = img.transpose(2,0,1)

        return torch.FloatTensor(img), torch.tensor(permu_idx, dtype=torch.int64)

# %%
ps = np.load('./permutation_30_sets.npy')
img_list = glob('./data/*')
jd = JIGSAW_DATASET(img_list, ps, normalize=False)
dl = DataLoader(jd,batch_size=16, shuffle=True)
model = CFN(in_feature=1024, num_classes=30).to("cpu")

for img, idx in dl :
    img = img.to("cpu")
    print(img.shape, idx)
    print(img)
    pred = model(img)
#           [ 53.,  53.,  53.,  ...,  54.,  52.,  53.],
#           ...,
#           [ 53.,  53.,  53.,  ...,  30.,  12.,  44.],
#           [ 54.,  53.,  53.,  ...,  17.,  11.,   6.],
#           [ 53.,  53.,  53.,  ...,   5.,   6.,   8.]],
#
#          [[140., 140., 140.,  ..., 139., 140., 140.],
#           [140., 140., 140.,  ..., 139., 139., 140.],
#           [140., 140., 140.,  ..., 139., 140., 140.],
#           ...,
#           [140., 140., 140.,  ...,  27.,   9.,  42.],
#           [140., 140., 140.,  ...,  17.,  11.,   6.],
#           [140., 140., 140.,  ...,   5.,   6.,   9.]],
#
#          [[243., 243., 243.,  ..., 245., 243., 243.],
#           [243., 243., 243.,  ..., 245., 243., 243.],
#           [243., 243., 243.,  ..., 245., 243., 243.],
#           ...,
#           [243., 243., 243.,  ...,  25.,   7.,  38.],
#           [244., 243., 243.,  ...,  17.,  11.,   5.],
#           [243., 243., 243.,  ...,   5.,   6.,   7.]],
#
#          ...,
#
#          [[ 53.,  53.,  53.,  ...,  53.,  53.,  53.],
#           [ 53.,  53.,  53.,  ...,  53.,  53.,  53.],
#           [ 53.,  53.,  53.,  ...,  53.,  53.,  53.],
#           ...,
#           [ 53.,  53.,  53.,  ...,  53.,  53.,  53.],
#           [ 53.,  53.,  53.,  ...,  53.,  53.,  53.],
#           [ 53.,  53.,  53.,  ...,  53.,  53.,  53.]],
#
#          [[140., 140., 140.,  ..., 140., 140., 140.],
#           [140., 140., 140.,  ..., 140., 140., 140.],
#           [140., 140., 140.,  ..., 140., 140., 140.],
#           ...,
#           [140., 140., 140.,  ..., 140., 140., 140.],
#           [140., 140., 140.,  ..., 140., 140., 140.],
#           [140., 140., 140.,  ..., 140., 140., 140.]],
#
#          [[243., 243., 243.,  ..., 243., 243., 243.],
#           [243., 243., 243.,  ..., 243., 243., 243.],
#           [243., 243., 243.,  ..., 243., 243., 243.],
#           ...,
#           [243., 243., 243.,  ..., 243., 243., 243.],
#           [243., 243., 243.,  ..., 243., 243., 243.],
#           [243., 243., 243.,  ..., 243., 243., 243.]]],
#
#
#         [[[  8.,   4.,  17.,  ...,  15.,  14.,  20.],
#           [ 18.,  33.,  36.,  ...,  18.,  31.,  19.],
#           [ 49.,  56.,  47.,  ...,  25.,  25.,  10.],
#           ...,
#           [ 12.,  12.,  13.,  ...,  21.,  27.,  33.],
#           [ 12.,  12.,  11.,  ...,  27.,  30.,  29.],
#           [ 12.,  11.,  10.,  ...,  28.,  25.,  28.]],
#
#          [[ 52.,  50.,  50.,  ...,  80.,  56.,  60.],
#           [ 75.,  94.,  99.,  ...,  74.,  77.,  66.],
#           [110., 120., 122.,  ...,  74.,  72.,  57.],
#           ...,
#           [ 36.,  37.,  38.,  ...,  84.,  91.,  95.],
#           [ 38.,  38.,  38.,  ...,  89.,  92.,  91.],
#           [ 37.,  38.,  39.,  ...,  92.,  88.,  90.]],
#
#          [[103., 101., 119.,  ..., 140., 113.,  99.],
#           [131., 152., 165.,  ..., 125., 129., 112.],
#           [189., 197., 189.,  ..., 121., 119., 104.],
#           ...,
#           [ 59.,  59.,  59.,  ..., 146., 163., 167.],
#           [ 55.,  55.,  55.,  ..., 152., 163., 161.],
#           [ 58.,  57.,  57.,  ..., 155., 158., 161.]],
#
#          ...,
#
#          [[ 34.,  35.,  33.,  ...,  20.,  23.,  18.],
#           [ 21.,  26.,  25.,  ...,  10.,  21.,  21.],
#           [ 17.,  20.,  17.,  ...,   8.,  12.,  16.],
#           ...,
#           [ 23.,  26.,   3.,  ...,   5.,   5.,   7.],
#           [ 30.,  28.,  11.,  ...,  15.,  19.,  14.],
#           [ 16.,  23.,  23.,  ...,  17.,  19.,  13.]],
#
#          [[ 35.,  33.,  34.,  ...,  60.,  65.,  66.],
#           [ 23.,  23.,  27.,  ...,  43.,  53.,  66.],
#           [ 18.,  17.,  18.,  ...,  39.,  41.,  61.],
#           ...,
#           [ 59.,  62.,  35.,  ...,  48.,  46.,  46.],
#           [ 72.,  70.,  50.,  ...,  53.,  54.,  55.],
#           [ 62.,  69.,  68.,  ...,  53.,  55.,  54.]],
#
#          [[ 45.,  44.,  43.,  ..., 117., 122., 117.],
#           [ 32.,  34.,  36.,  ...,  90., 100., 114.],
#           [ 28.,  28.,  28.,  ...,  69.,  72., 106.],
#           ...,
#           [ 89.,  89.,  63.,  ...,  93.,  93.,  89.],
#           [109., 104.,  84.,  ...,  94.,  96.,  98.],
#           [106., 110., 108.,  ...,  95.,  97.,  93.]]]])
# tensor([[0.9328, 1.1273, 1.0447, 1.1677, 1.0788, 0.9795, 1.1561, 0.9692, 1.1047,
#          1.1495, 1.0330, 1.0037, 0.8679, 0.9582, 0.8810, 0.9716, 0.9439, 1.1108,
#          0.9940, 1.0208, 1.0470, 1.1477, 1.0188, 0.8058, 1.0490, 1.2847, 1.1792,
#          1.1398, 1.0982, 1.0779],
#         [0.9350, 1.1293, 1.0455, 1.1650, 1.0742, 0.9776, 1.1552, 0.9665, 1.0993,
#          1.1531, 1.0375, 1.0065, 0.8719, 0.9599, 0.8812, 0.9784, 0.9453, 1.1151,
#          0.9926, 1.0162, 1.0545, 1.1460, 1.0171, 0.8048, 1.0534, 1.2892, 1.1710,
#          1.1387, 1.1007, 1.0762],
#         [0.9342, 1.1267, 1.0479, 1.1652, 1.0751, 0.9817, 1.1550, 0.9668, 1.0994,
#          1.1542, 1.0351, 1.0051, 0.8748, 0.9588, 0.8814, 0.9751, 0.9347, 1.1130,
#          0.9892, 1.0223, 1.0506, 1.1499, 1.0206, 0.8073, 1.0522, 1.2928, 1.1754,
#          1.1398, 1.0981, 1.0765],
#         [0.9359, 1.1295, 1.0469, 1.1643, 1.0754, 0.9755, 1.1550, 0.9684, 1.0994,
#          1.1527, 1.0338, 1.0044, 0.8705, 0.9583, 0.8826, 0.9774, 0.9401, 1.1129,
#          0.9951, 1.0197, 1.0524, 1.1518, 1.0201, 0.8067, 1.0522, 1.2887, 1.1779,
#          1.1400, 1.1009, 1.0775],
#         [0.9382, 1.1312, 1.0489, 1.1643, 1.0752, 0.9768, 1.1553, 0.9715, 1.0981,
#          0.9968, 1.0199, 1.0538, 1.1518, 1.0175, 0.8089, 1.0524, 1.2871, 1.1747,
#          1.1410, 1.1017, 1.0771],
#         [0.9329, 1.1289, 1.0471, 1.1638, 1.0750, 0.9809, 1.1508, 0.9703, 1.1012,
#          1.1537, 1.0317, 1.0044, 0.8731, 0.9559, 0.8798, 0.9731, 0.9390, 1.1120,
#          0.9962, 1.0218, 1.0530, 1.1481, 1.0198, 0.8091, 1.0514, 1.2893, 1.1777,
#          1.1381, 1.0979, 1.0758],
#         [0.9347, 1.1304, 1.0481, 1.1641, 1.0757, 0.9784, 1.1542, 0.9685, 1.0955,
#          1.1516, 1.0357, 0.9972, 0.8716, 0.9592, 0.8845, 0.9793, 0.9382, 1.1096,
#          0.9928, 1.0152, 1.0544, 1.1464, 1.0176, 0.8069, 1.0508, 1.2893, 1.1761,
#          1.1423, 1.1027, 1.0775],
#         [0.9378, 1.1308, 1.0479, 1.1620, 1.0727, 0.9819, 1.1546, 0.9676, 1.0957,
#          1.1531, 1.0352, 1.0015, 0.8764, 0.9592, 0.8831, 0.9782, 0.9395, 1.1136,
#          0.9942, 1.0158, 1.0593, 1.1494, 1.0197, 0.8066, 1.0534, 1.2914, 1.1749,
#          1.1417, 1.1009, 1.0781]], grad_fn=<AddmmBackward0>)

# %%
import matplotlib.pyplot as plt

img_ = np.array(img[0], dtype=np.uint8)
print(ps[idx[0]])
print(pred[0])
fig, axs = plt.subplots(3, 3, figsize=(9,9))
axs = axs.flatten()
for i in range(9) :
    axs[i].imshow(img_[i*3:(i+1)*3, :, :].transpose(1,2,0))
#     axs[idx].set_axis_off()
plt.subplots_adjust(left=0.3, bottom=0.3,  right=0.7 , top=0.7, wspace=0.01, hspace=0.01)
plt.show()
# Out:
# [7 5 4 2 9 6 8 3 1]
# tensor([0.9328, 1.1273, 1.0447, 1.1677, 1.0788, 0.9795, 1.1561, 0.9692, 1.1047,
#         1.1495, 1.0330, 1.0037, 0.8679, 0.9582, 0.8810, 0.9716, 0.9439, 1.1108,
#         0.9940, 1.0208, 1.0470, 1.1477, 1.0188, 0.8058, 1.0490, 1.2847, 1.1792,
#         1.1398, 1.0982, 1.0779], grad_fn=<SelectBackward0>)

# %%
img_ = np.array(img[3], dtype=np.uint8)
print(ps[idx[3]])
print(pred[3])
fig, axs = plt.subplots(3, 3, figsize=(9,9))
axs = axs.flatten()
for i in range(9) :
    axs[i].imshow(img_[i*3:(i+1)*3, :, :].transpose(1,2,0))
#     axs[idx].set_axis_off()
plt.subplots_adjust(left=0.3, bottom=0.3,  right=0.7 , top=0.7, wspace=0.01, hspace=0.01)
plt.show()
# Out:
# [4 3 2 7 9 8 1 5 6]
# tensor([0.9359, 1.1295, 1.0469, 1.1643, 1.0754, 0.9755, 1.1550, 0.9684, 1.0994,
#         1.1527, 1.0338, 1.0044, 0.8705, 0.9583, 0.8826, 0.9774, 0.9401, 1.1129,
#         0.9951, 1.0197, 1.0524, 1.1518, 1.0201, 0.8067, 1.0522, 1.2887, 1.1779,
#         1.1400, 1.1009, 1.0775], grad_fn=<SelectBackward0>)

# %%
learning_rate = 0.01
epochs = 50
batch_size = 16
device = 'cuda:0'
permutation_path = './permutation_3_sets.npy'
img_path = './data/*'
num_classes = 3

model = CFN(in_feature=1024, num_classes=num_classes).to(device)
optimizer = torch.optim.SGD(params=model.parameters(), lr=learning_rate)
criterion  = torch.nn.CrossEntropyLoss()



ps = np.load(permutation_path)
img_list = glob(img_path)


jigsaw_dataset = JIGSAW_DATASET(img_list, ps, normalize=False)
dataloader = DataLoader(jigsaw_dataset, batch_size=batch_size, shuffle=True)

for E in range(1, epochs+1) :
    for img, label in dataloader:
        model.train()
        img = img.to(device)
        label = label.to(device)
        
        optimizer.zero_grad()
#         print(img.shape)
        pred = model(img)
        loss = criterion(pred, label)
        
        loss.backward()
        optimizer.step()
        
    print("Epochs : ", E, " Loss : ", loss)
# Out:
# Epochs :  1  Loss :  tensor(1.0359, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  2  Loss :  tensor(1.0271, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  3  Loss :  tensor(1.1665, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  4  Loss :  tensor(1.0987, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  5  Loss :  tensor(1.1203, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  6  Loss :  tensor(1.0979, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  7  Loss :  tensor(1.0919, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  8  Loss :  tensor(1.1107, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  9  Loss :  tensor(1.0551, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  10  Loss :  tensor(1.0994, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  11  Loss :  tensor(1.1061, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  12  Loss :  tensor(1.0977, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  13  Loss :  tensor(1.1006, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  14  Loss :  tensor(1.2246, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  15  Loss :  tensor(1.0810, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  16  Loss :  tensor(1.0802, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  17  Loss :  tensor(1.0974, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  18  Loss :  tensor(1.0898, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  19  Loss :  tensor(1.0866, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  20  Loss :  tensor(1.0931, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  21  Loss :  tensor(1.0295, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  22  Loss :  tensor(1.0880, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  23  Loss :  tensor(1.0460, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  24  Loss :  tensor(0.9227, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  25  Loss :  tensor(1.0422, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  26  Loss :  tensor(0.9445, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  27  Loss :  tensor(1.0545, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  28  Loss :  tensor(1.2059, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  29  Loss :  tensor(0.9056, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  30  Loss :  tensor(1.0744, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  31  Loss :  tensor(1.4600, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  32  Loss :  tensor(1.0873, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  33  Loss :  tensor(1.0764, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  34  Loss :  tensor(1.2113, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  35  Loss :  tensor(1.0963, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  36  Loss :  tensor(1.0998, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  37  Loss :  tensor(1.0984, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  38  Loss :  tensor(1.0905, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  39  Loss :  tensor(1.1037, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  40  Loss :  tensor(0.9761, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  41  Loss :  tensor(1.0543, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  42  Loss :  tensor(1.2022, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  43  Loss :  tensor(1.0681, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  44  Loss :  tensor(1.0456, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  45  Loss :  tensor(0.8400, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  46  Loss :  tensor(1.0711, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  47  Loss :  tensor(1.1152, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  48  Loss :  tensor(0.8566, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  49  Loss :  tensor(1.0515, device='cuda:0', grad_fn=<NllLossBackward0>)
# Epochs :  50  Loss :  tensor(1.1177, device='cuda:0', grad_fn=<NllLossBackward0>)

# %%
p = model(img)

# %%
display(p)
display(torch.argmax(p,dim=1))
display(label)
# Out:
# tensor([[0.4059, 1.3674, 1.0242],
#         [0.9075, 0.7888, 1.2498],
#         [0.5490, 1.1710, 1.1164],
#         [0.7907, 0.7996, 1.3141],
#         [0.0432, 1.9286, 0.7108],
#         [0.8008, 0.8633, 1.2463]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([1, 2, 1, 2, 1, 2], device='cuda:0')
# tensor([2, 0, 1, 2, 1, 1], device='cuda:0')
